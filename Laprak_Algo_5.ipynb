# %% [markdown]
# <a href="https://colab.research.google.com/github/wahidninis-del/Praktikum-Algoritma-Pak-Anung/blob/main/Laprak_Algo_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
#Annisa Qurrotu Aini Wahid
#065002500031
"""
total = 0
jumlah = 0

while True:
    huruf = input("masukkan nilai: ").upper()

    if huruf == "":
        break

    if huruf == "A":
        nilai = 4.00
    elif huruf == "A-":
        nilai = 3.75
    elif huruf == "B+":
        nilai = 3.50
    elif huruf == "B":
        nilai = 3.00
    elif huruf == "B-":
        nilai = 2.75
    elif huruf == "C+":
        nilai = 2.50
    elif huruf == "C":
        nilai = 2.00
    elif huruf == "C-":
        nilai = 1.75
    elif huruf == "D":
        nilai = 1.50
    elif huruf == "E":
        nilai = 1.25
    else:
        print("Input tidak valid. Silakan coba lagi.")

    print(f"nilai = {nilai}")
    total += nilai
    jumlah += 1

if jumlah > 0:
    rata = total / jumlah
    print(f"Rata - rata nya adalah: {rata:.2f}")
else:
    print("Tidak ada nilai yang dimasukkan.")
# Out:
# masukkan nilai: A
# nilai = 4.0
# masukkan nilai: A-
# nilai = 3.75
# masukkan nilai: B+
# nilai = 3.5
# masukkan nilai: B
# nilai = 3.0
# masukkan nilai: B-
# nilai = 2.75
# masukkan nilai: C+
# nilai = 2.5
# masukkan nilai: C
# nilai = 2.0
# masukkan nilai: C-
# nilai = 1.75
# masukkan nilai: D
# nilai = 1.5
# masukkan nilai: E
# nilai = 1.25
# masukkan nilai:
# Rata - rata nya adalah: 2.60

# %%
"""
#Annisa Qurrotu Aini Wahid
#065002500031
#Latihan 2
"""
total = 0.0
while True:
  umur = input("Masukkan umur: ")

  if umur == "" :
    break
  umur = int(umur)

  if umur <= 2:
    harga = 0
    print("Gratis")
  elif 3 <= umur <= 12:
    harga = 14
    print("Harga $14.00")
  elif umur >= 65:
    harga = 18
    print("Harga $18.00")
  else:
    harga = 23
    print("Harga $23.00")

  total += harga
  print(f"Total yang harus dibayar: {total:.2f}")

uang = float(input("Masukkan jumlah uang: "))
kembalian = uang - total
print(f"Running kembalian: {kembalian:.2f}")
# Out:
# Masukkan umur: 1
# Gratis
# Total yang harus dibayar: 0.00
# Masukkan umur: 19
# Harga $23.00
# Total yang harus dibayar: 23.00
# Masukkan umur: 66
# Harga $18.00
# Total yang harus dibayar: 41.00
# Masukkan umur: 11
# Harga $14.00
# Total yang harus dibayar: 55.00
# Masukkan umur:
# Masukkan jumlah uang: 1000000
# Running kembalian: 999945.00
