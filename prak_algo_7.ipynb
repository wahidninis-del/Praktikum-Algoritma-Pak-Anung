# %% [markdown]
# <a href="https://colab.research.google.com/github/wahidninis-del/Praktikum-Algoritma-Pak-Anung/blob/main/prak_algo_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Fungsi untuk mengecek apakah angka adalah bilangan prima
def cek_prima(angka):
    if angka < 2:
        return False
    for i in range(2, int(angka**0.5) + 1):
        if angka % i == 0:
            return False
    return True

# Fungsi utama untuk menampilkan hasil
def tampil_hasil_prima(angka):
    if cek_prima(angka):
        print(f"{angka} adalah bilangan Prima")
    else:
        print(f"{angka} bukanlah bilangan Prima")

# Program utama menggunakan perulangan
while True:
    angka = int(input("Masukkan angka (0 untuk berhenti): "))
    if angka == 0:
        print("Program selesai.")
        break
    hasil(angka)
# Out:
# Masukkan angka (0 untuk berhenti): 3
# 3 adalah bilangan Prima
# Masukkan angka (0 untuk berhenti): 4
# 4 bukanlah bilangan Prima
# Masukkan angka (0 untuk berhenti): 0
# Program selesai.

# %%
"""
#Annisa Qurrotu Aini Wahid
#065002500031
"""
# Fungsi untuk mengecek apakah angka adalah bilangan prima
def cek_prima(x):
    if x <= 1:
        return False
    elif x == 2:
        return True
    for i in range(2, x):
            if x % i == 0:
                return False
    return True
# Fungsi untuk menampilkan hasil
def tampil_hasil_prima(angka, status):
    if status:
        print(f"{angka} adalah bilangan Prima")
    else:
        print(f"{angka} bukanlah bilangan Prima")

# Program menggunakan perulangan
while True:
    angka_input = int(input("Masukkan Angka (0 untuk berhenti): "))
    if angka_input == 0:
        print("Program selesai.")
        break

    status = cek_prima(angka_input)
    tampil_hasil_prima(angka_input, status)
# Out:
# Masukkan Angka (0 untuk berhenti): 3
# 3 adalah bilangan Prima
# Masukkan Angka (0 untuk berhenti): 4
# 4 bukanlah bilangan Prima
# Masukkan Angka (0 untuk berhenti): 0
# Program selesai.

# %%
def dapatkan_akhiran_ordinal(n):
    if n == 0:
        return 'th'

    if 10 <= n % 100 <= 20:
        akhiran = 'th'
    else:
        digit_terakhir = n % 10

        if digit_terakhir == 1:
            akhiran = 'st'
        elif digit_terakhir == 2:
            akhiran = 'nd'
        elif digit_terakhir == 3:
            akhiran = 'rd'
        else:
            akhiran = 'th'

    return akhiran


print("Ordinal Number")
print("Ketik 0 untuk menghentikan program")

while True:
    angka = int(input("Masukkan angka: "))

    if angka == 0:
        print("Terima kasih telah menggunakan program saya.")
        break

    suffix = dapatkan_akhiran_ordinal(angka)

    print(f"({angka}, '{suffix}')")
# Out:
# Ordinal Number
# Ketik 0 untuk menghentikan program
# Masukkan angka: 1
# (1, 'st')
# Masukkan angka: 2
# (2, 'nd')
# Masukkan angka: 3
# (3, 'rd')
# Masukkan angka: 0
# Terima kasih telah menggunakan program saya.
