# %% [markdown]
# <a href="https://colab.research.google.com/github/wahidninis-del/Praktikum-Algoritma-Pak-Anung/blob/main/Laporan_Algoritma_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
*Annisa Qurrotu Aini Wahid
*065002500031
*Latihan 1
"""
for i in range(7,0,-1):
  print (str(i) * i)
# Out:
# 7777777
# 666666
# 55555
# 4444
# 333
# 22
# 1

# %%
"""
*Annisa Qurrotu Aini Wahid
*065002500031
*Latihan 2
"""
bulan = int(input("Masukkan bulan (1-12): "))
while bulan < 1 or bulan > 12:
  print("Bulan tidak valid!coba lagi")
  bulan = int(input("Masukkan bulan (1-12): "))

tahun = int(input("Masukkan tahun: "))

if bulan in [1, 3, 5, 7, 8, 10, 12]:
  hari = 31
elif bulan in [4, 6, 9, 11]:
  hari = 30
else:
  if(tahun % 4 == 0 and tahun % 100 != 0) or (tahun % 400 == 0):
    hari = 29
  else:
    hari = 28

print(f"Jumlah hari pada bulan {bulan} tahun {tahun} adalah {hari} hari.")
# Out:
# Masukkan bulan (1-12): 12
# Masukkan tahun: 2022
# Jumlah hari pada bulan 12 tahun 2022 adalah 31 hari.
