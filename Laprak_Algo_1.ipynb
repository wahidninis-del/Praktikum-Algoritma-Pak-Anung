# %% [markdown]
# <a href="https://colab.research.google.com/github/wahidninis-del/Praktikum-Algoritma-Pak-Anung/blob/main/Laprak_Algo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
*Annisa Qurrotu Aini Wahid
*065002500031
"""
print("Masukkan data kamu dengan sesuai")
nama = input("Masukkan nama kamu: ")
alamat = input("Masukkan alamat kamu")
nama_kampus = input("Masukkan nama kampus kamu")
jurusan = input("Masukkan jurusan kamu")
gedung = input("Masukkan gedung jurusan kamu")

print("Berikut data kamu!")

print(f"Halo nama saya {nama}, saya tinggal di {alamat}, saya kuliah di {nama_kampus}, jurusan saya {jurusan}, di gedung {gedung}, dan saya siap ikuti praktikum algoritma")
# Out:
# Masukkan data kamu dengan sesuai
# Masukkan nama kamu: Annisa
# Masukkan alamat kamuBogor
# Masukkan nama kampus kamuTrisakti
# Masukkan jurusan kamuSistem Informasi
# Masukkan gedung jurusan kamuE
# Berikut data kamu!
# Halo nama saya Annisa, saya tinggal di Bogor, saya kuliah di Trisakti, jurusan saya Sistem Informasi, di gedung E, dan saya siap ikuti praktikum algoritma

# %%
"""
*Annisa Qurrotu Aini Wahid
*065002500031
*Laporan Praktikum Algoritma - Kamis, 18 September 2025
"""
print("Hitung luas bangunan!")
panjang = int(input("Masukkan panjang ruangan:"))
lebar = int(input("Masukkan lebar ruangan:"))
satuan = input("Masukkan satuan ruangan")
luas = int(input("Masukkan panjang * lebar"))
print(luas)
print(f"luas ruangan dengan panjang {panjang} * lebar {lebar} adalah {luas}")
# Out:
# Hitung luas bangunan!
# Masukkan panjang ruangan:7
# Masukkan lebar ruangan:5
# Masukkan satuan ruanganmeter
# Masukkan panjang * lebar35
# 35
# luas ruangan dengan panjang 7 * lebar 5 adalah 35

# %%
"""
*Annisa Qurrotu Aini Wahid
*065002500031
"""

print("Hitung body mass index!")
nama = input("Masukkan nama kamu:")
berat = int(input("berat badan kamu:"))
tinggi = float(input("tinggi badan kamu:"))
bmi =  berat / (tinggi * tinggi)
print("")
print(f"Annisa body mass indexmu adalah {bmi}")
# Out:
# Hitung body mass index!
# Masukkan nama kamu:Annisa
# berat badan kamu:44
# tinggi badan kamu:1.56
#
# Annisa body mass indexmu adalah 18.080210387902692
